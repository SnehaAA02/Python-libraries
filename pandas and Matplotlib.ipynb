# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
data={
    "ages":[14,18,24,42],
    "heights":[165,180,176,184]
}

# %%
#df=pd.DataFrame(data)

# %%
df=pd.DataFrame(data,index=['James','Bob','Amy','Dave'])
print(df.loc["Bob"])
# Out:
# ages        18
# heights    180
# Name: Bob, dtype: int64

# %%
print(df["ages"])
# Out:
# James    14
# Bob      18
# Amy      24
# Dave     42
# Name: ages, dtype: int64

# %%
print(df.iloc[2])
# Out:
# ages        24
# heights    176
# Name: Amy, dtype: int64

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length','sepal-width','petal-length','petal-width','class']
df =pd.read_csv(url,names=names)

# %%
print(df.head())
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal-length  150 non-null    float64
#  1   sepal-width   150 non-null    float64
#  2   petal-length  150 non-null    float64
#  3   petal-width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
df.drop('sepal-width',axis=1,inplace=True)

# %%
print(df.head())
# Out:
#    sepal-length  petal-length  petal-width        class
# 0           5.1           1.4          0.2  Iris-setosa
# 1           4.9           1.4          0.2  Iris-setosa
# 2           4.7           1.3          0.2  Iris-setosa
# 3           4.6           1.5          0.2  Iris-setosa
# 4           5.0           1.4          0.2  Iris-setosa

# %%
df['sepal-length'].value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal-length, dtype: int64

# %%
print(df.groupby('class').size())
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
print(df.groupby('class').sum())
# Out:
#                  sepal-length  petal-length  petal-width
# class
# Iris-setosa             250.3          73.2         12.2
# Iris-versicolor         296.8         213.0         66.3
# Iris-virginica          329.4         277.6        101.3

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df[['sepal-length','petal-length']].plot()
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].head().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].head().plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].head(30).plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].head(30).plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['sepal-length','petal-length']].head(30).plot(kind='area',stacked=False)
# Out:
# <AxesSubplot:>

# %%
df[['sepal-length','petal-length']].head(30).plot(kind='scatter',x='petal-length',y='sepal-length')
# Out:
# <AxesSubplot:xlabel='petal-length', ylabel='sepal-length'>

# %%
df['sepal-length'].head(30).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='sepal-length'>
